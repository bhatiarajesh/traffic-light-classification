# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Classify a traffic light based on simple geometric properties
# Expects a gray-scale image
def classifyTL(image_data):
    print('____________________________________________________________________')
    # get the image center geometry
    midX = int(image_data.shape[1]/2)
    midY = int(image_data.shape[0]/2)
    thirdY = int(image_data.shape[0]/3)
    p = int(thirdY/3) #patch size
    print("patch size=",p)
    # get the center point of each ROI
    rROI = ( int(thirdY/2) , midX )
    yROI = ( midY, midX )
    gROI = ( midY+thirdY , midX )
    print("center points:",rROI,yROI,gROI)
    print("patches:",rROI[0]-p,rROI[0]+p, rROI[1]-p,rROI[1]+p,
yROI[0]-p,yROI[0]+p, yROI[1]-p,yROI[1]+p,
gROI[0]-p,gROI[0]+p, gROI[1]-p,gROI[1]+p)
    # find the average from each center patch
    rROI = int(np.mean(image_data[rROI[0]-p:rROI[0]+p, rROI[1]-p:rROI[1]+p]))
    yROI = int(np.mean(image_data[yROI[0]-p:yROI[0]+p, yROI[1]-p:yROI[1]+p]))
    gROI = int(np.mean(image_data[gROI[0]-p:gROI[0]+p, gROI[1]-p:gROI[1]+p]))
    print("means:",rROI,yROI,gROI)
    # perform simple brightness comparisons
    if (gROI > yROI) and (gROI > rROI):
        print(">>> GREEN <<<")
    elif (yROI > gROI) and (yROI > rROI):
        print(">>> YELLOW <<<")
    elif (rROI > yROI) and (rROI > gROI):
        print(">>> RED <<<")

    imgplot = plt.imshow(image_data, cmap='gray', vmin=0, vmax=255)
    plt.show()
    if (gROI > yROI) and (gROI > rROI):
        return 1
    else:
        return 0


img = cv2.imread("../image/red002.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
# Out:
# ____________________________________________________________________
# patch size= 23
# center points: (35, 39) (107, 39) (178, 39)
# patches: 12 58 16 62 84 130 16 62 155 201 16 62
# means: 218 28 24
# >>> RED <<<
# 0

# %%
img = cv2.imread("../image/red000.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/red001.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/red002.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/red003.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/red004.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/red005.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/yellow000.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/yellow001.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/yellow002.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/yellow003.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green000.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green001.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green002.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green003.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green004.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
img = cv2.imread("../image/green005.png")
image_data = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)[:,:,2]
print(classifyTL(image_data))
# Out:
# ____________________________________________________________________
# patch size= 12
# center points: (18, 22) (56, 22) (93, 22)
# patches: 6 30 10 34 44 68 10 34 81 105 10 34
# means: 235 117 103
# >>> RED <<<
# 0
# ____________________________________________________________________
# patch size= 21
# center points: (31, 34) (95, 34) (158, 34)
# patches: 10 52 13 55 74 116 13 55 137 179 13 55
# means: 236 18 19
# >>> RED <<<
# 0
# ____________________________________________________________________
# patch size= 23
# center points: (35, 39) (107, 39) (178, 39)
# patches: 12 58 16 62 84 130 16 62 155 201 16 62
# means: 218 28 24
# >>> RED <<<
# 0
# ____________________________________________________________________
# patch size= 19
# center points: (29, 32) (89, 32) (148, 32)
# patches: 10 48 13 51 70 108 13 51 129 167 13 51
# means: 188 51 48
# >>> RED <<<
# 0
# ____________________________________________________________________
# patch size= 9
# ...
